# %% [markdown]
# <a href="https://colab.research.google.com/github/sierrastarbrady/COMM557/blob/master/NBA_INJURY_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1) NBA Injuries Dataset
# Main dataset used for KMeans clustering; for documentation please refer to, https://www.kaggle.com/datasets/ghopkins/nba-injuries-2010-2018?resource=download
#
# ### Goals
# 1. Clean and preprocess dataset (remove null columns and rename features)
#
#
# 2. Research and implement key feature engineering techniques
#     - (One-hot-encoding for vectorization, and possibly use PCA (Principle Component Analysis), NLP (Natural Language processing) or topic modeling
#
#
# 3. Begin clustering vectors found from one-hot encoding using KMeans Algorithm and assess performance

# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv('/NBA DATA/injuries_2010-2020.csv')
df1.head(50)
# Out:
#           Date          Team Acquired           Relinquished  \
# 0   2010-10-03         Bulls      NaN          Carlos Boozer
# 1   2010-10-06       Pistons      NaN          Jonas Jerebko
# 2   2010-10-06       Pistons      NaN          Terrico White
# 3   2010-10-08       Blazers      NaN             Jeff Ayres
# 4   2010-10-08          Nets      NaN            Troy Murphy
# 5   2010-10-08       Pistons      NaN          Jonas Jerebko
# 6   2010-10-08       Pistons      NaN          Terrico White
# 7   2010-10-09       Nuggets      NaN          Al Harrington
# 8   2010-10-12         Bucks      NaN       Darington Hobson
# 9   2010-10-12         Kings      NaN       Samuel Dalembert
# 10  2010-10-17       Bobcats      NaN        Dominic McGuire
# 11  2010-10-18      Warriors      NaN           Lou Amundson
# 12  2010-10-19          Suns      NaN         Josh Childress
# 13  2010-10-22          Heat      NaN            Mike Miller
# ...

# %%
df1.shape
# Out:
# (36436, 5)

# %%
df1.describe()
# Out:
#               Date   Team       Acquired Relinquished              Notes
# count        36436  36433          13506        22924              36435
# unique        2104     32           1112         1156               3114
# top     2017-04-12  Spurs  Kawhi Leonard  Eric Gordon  activated from IL
# freq           148   1512             81          123              10367

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36436 entries, 0 to 36435
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          36436 non-null  object
#  1   Team          36433 non-null  object
#  2   Acquired      13506 non-null  object
#  3   Relinquished  22924 non-null  object
#  4   Notes         36435 non-null  object
# dtypes: object(5)
# memory usage: 1.4+ MB

# %%
#Run cell to find each unique description in dataset (Beware the output is large)
unique_descriptions = df1['Notes'].unique()

# print the unique descriptions
for description in unique_descriptions:
    print(description)

# %%
# Run cell to find each unique Team
unique_descriptions1 = df1['Team'].unique()

for d in unique_descriptions1:
    print(d)
# Out:
# Bulls
# Pistons
# Blazers
# Nets
# Nuggets
# Bucks
# Kings
# Bobcats
# Warriors
# Suns
# Heat
# Thunder
# Timberwolves
# Celtics
# Lakers
# Rockets
# 76ers
# Cavaliers
# Clippers
# Grizzlies
# Hawks
# Hornets
# Jazz
# Knicks
# Mavericks
# Pacers
# Raptors
# Spurs
# Magic
# Wizards
# Pelicans
# nan
# Bullets

# %%
df1["Notes"].value_counts()
#Going to need to figure out how to encode the last few words in sentence to a unique identifier
# Out:
# activated from IL                                              10367
# placed on IL                                                    4467
# returned to lineup                                              3021
# placed on IL with illness                                        444
# rest (DTD)                                                       370
#                                                                ...
# surgery to repair fractured orbital bone (out indefinitely)        1
# sprained left ankle (P) / knee (CBC) (DNP)                         1
# fractured left cheekbone (DNP)                                     1
# placed on IL with hip injury (P)                                   1
# surgery on right toe to repair fracture (out indefinitely)         1
# Name: Notes, Length: 3114, dtype: int64

# %%
#Find sum of null values
null_feats_1 = df1["Team"].isnull().sum()
null_feats_2 = df1["Acquired"].isnull().sum()
null_feats_3 = df1["Relinquished"].isnull().sum()

print("There are", null_feats_1 ,"null entries in the Team column")
print("There are", null_feats_2 ,"null entries in the Acquired column")
print("There are", null_feats_3 ,"null entries in the Relinquished column")
# Out:
# There are 3 null entries in the Team column
# There are 22930 null entries in the Acquired column
# There are 13512 null entries in the Relinquished column

# %% [markdown]
# ## 2) NBA Player Stats (NOT WORKING IN COLLAB RIGHT NOW)
# Information on key player stats to use for predictions; for documentation please refer to https://data.world/etocco/nba-player-stats

# %%
df2 = pd.read_csv('/NBA DATA/nba_player_stats.csv')
df2
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-17-2222d6b41026> in <module>
# ----> 1 df2 = pd.read_csv('/NBA DATA/nba_player_stats.csv')
#       2 df2
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df3 = pd.read_csv('nba_player_stats_2.csv')
df3
# Out:
#         rk               player pos  age   tm   g  gs    mp   fg   fga  ...  \
# 0        1   Mahmoud Abdul-Rauf  PG   28  SAC  31   0  17.1  3.3   8.8  ...
# 1        2    Tariq Abdul-Wahad  SG   23  SAC  59  16  16.3  2.4   6.1  ...
# 2        3  Shareef Abdur-Rahim  SF   21  VAN  82  82  36.0  8.0  16.4  ...
# 3        4       Cory Alexander  PG   24  TOT  60  22  21.6  2.9   6.7  ...
# 4        4       Cory Alexander  PG   24  SAS  37   3  13.5  1.6   3.9  ...
# ...    ...                  ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 14568  601       Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  ...
# 14569  602           Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  ...
# 14570  603       Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  ...
# 14571  604          Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  ...
# 14572  605          Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  ...
#
# ...

# %% [markdown]
# ## 3) NBA API Data
#
# For documentation on how to use API to find player information please refer to https://github.com/swar/nba_api
# - Before running make sure to open anaconda terminal and input: pip install nba_api

# %% [markdown]
# ### Official NBA Stats

# %%
from nba_api.stats.endpoints import playercareerstats

# Nikola Jokić
career = playercareerstats.PlayerCareerStats(player_id='203999') 

# pandas data frames (optional: pip install pandas)
career.get_data_frames()[0]

# json
career.get_json()

# dictionary
career.get_dict()

# %% [markdown]
# ### NBA Live Data

# %%
from nba_api.live.nba.endpoints import scoreboard

# Today's Score Board
games = scoreboard.ScoreBoard()

# json
games.get_json()

# dictionary
games.get_dict()
